# %% [markdown]
# # Cookie Recommender: Find Your Perfect Chocolate Chip Cookie

# %% [markdown]
# This project is a cookie recommendation program that helps users find the chocolate chip cookie recipe that best matches their preferences. Users answers a series of questions about the type of cookie they are craving, including size, thickness, texture, and flavor profile. The program uses a scoring system to compare the user's preferences against five different cookie recipes and recommends the best match.

# %% [markdown]
# ## Project Code
#
# Demonstrate how your project works here! (If it doesn't work from the notebook, describe what graders should do to execute your project.)

# %%
import module # your module.py file

# %%
# Do a bunch of things.
module.run_cookie_quiz()
# Out:
# Welcome to the Cookie Recommender!
#
# Which best describes what you're craving today?
# 1. classic indulgent cookie
# 2. healthy gluten-free cookie
# Enter the number of your choice:  1
# What size cookie sounds best?
# 1. giant
# 2. regular
# Enter the number of your choice:  2
# Which thickness do you prefer?
# 1. thick
# 2. thin
# Enter the number of your choice:  1
# Which texture sounds best?
# 1. soft
# 2. chewy
# 3. crispy edges
# Enter the number of your choice:  2
# Which flavor profile sounds most appealing?
# 1. chocolatey
# 2. buttery
# 3. caramelized
# Enter the number of your choice:  3
# Your Cookie Match: Brown Butter Cookie
#
# Match Score: 5/5
#
# A chewy cookie with nutty brown butter, caramelized flavor, and sea salt.
#
# Why we chose it:
# - classic
# - regular
# - thick
# - chewy
# - caramelized
#
# What would you like to do next?
# 1. view recipe
# 2. get another recommendation
# 3. exit
# Enter the number of your choice:  1
# Recipe for Brown Butter Cookie
#
# ...

# %% [markdown]
# #### Testing
#
# Run your tests. Sample code is provided below; you may need to edit this, depending upon how you've set up your tests.

# %%
# test it out
import unittest
import tests  # your tests.py file

unittest.main(tests.__name__, argv=[''], verbosity=2, exit=False)
# Out:
# test_calculate_score_counts_matching_traits (tests.TestCookieRecommender.test_calculate_score_counts_matching_traits) ... ok
# test_cookie_class_stores_attributes (tests.TestCookieRecommender.test_cookie_class_stores_attributes) ... ok
# test_get_matching_traits (tests.TestCookieRecommender.test_get_matching_traits) ... ok
# test_recommend_cookie_returns_nyc_style_cookie (tests.TestCookieRecommender.test_recommend_cookie_returns_nyc_style_cookie) ... ok
# test_validate_choice_accepts_valid_choice (tests.TestCookieRecommender.test_validate_choice_accepts_valid_choice) ... ok
#
# ----------------------------------------------------------------------
# Ran 5 tests in 0.007s
#
# OK

# %% [markdown]
# #### GenAI Statement
#
# I used GenAI as a learning and development tool throughout this project. GenAI helped me brainstorm project ideas, design the overall program structure, improve code organization, and identify bugs during development. It also provided guidance on classes, functions, documentation, and code style. I reviewed and modified all code myself to ensure I understood how each part of the project worked and could explain it during the oral exam.

# %% [markdown]
# #### Extra Credit (*optional*)
#
# I had no prior Python experience, so this project challenged me to apply multiple concepts from class on a larger scale. I implemented a custom scoring algorithm that compares user preferences against cookie traits to determine the best recommendation. I also organized the project using a custom Cookie class, multiple functions, recipe storage, and unit testing. Users are able receive a personalized recommendation and view complete recipe details, which goes beyond the project requirements.
